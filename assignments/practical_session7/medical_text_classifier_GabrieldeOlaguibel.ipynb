# %% [markdown]
# ## Assignment 7: Medical Text Classification (NLP)
# This task involves creating clasiffy patient transcriptions into 4 categories:
# - Surgery
# - Medical Records
# - Internal Medicine
# - Other
#
# I have been given the following data files:
# - X.csv: A fully processed dataset. Simplified to 4 classes
# - classes.txt: Text file describing the dataset's classes: Surgery, Medical Records, Internal Medicine and Other
# - train.csv: Training data subset. Contains 90% of the X.csv processed file.
# - Test data subset. Contains 10% of the X.csv processed file.
#
# I'm also given the following data source files:
# - mtsamples.csv: Compiled from Kaggle's medical transcriptions dataset by Tara Boyle, scraped from Transcribed Medical Transcription Sample Reports and Examples
# - clinical-stopwords.txt: Compiled from Dr. Kavita Ganesan clinical-concepts repository. See the Discovering Related Clinical Concepts Using Large Amounts of Clinical Notes paper.
# - vocab.txt: Generated vocabulary text files for Natural Language Processing (NLP) using the Systematized Nomenclature of Medicine International (SNMI) data.

# %% [markdown]
# # Google Colab Link: https://colab.research.google.com/drive/1lREcVRGtD4pk1iyQrAeaqS5RffhdENAi?usp=sharing
#
# ### *Important*: The code for the models are made train on CPU (it will cause errors if you train on GPU)

# %%
# Library Imports
import pandas as pd
import numpy as np
import torch
import nltk
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec
from torch.utils.data import TensorDataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Load the Data

# %%
# Download NLTK's punkt tokenizer model
nltk.download('punkt')

# Load Datasets
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')

# load the the text data
with open('clinical-stopwords.txt', 'r') as file:
    stopwords = file.read().splitlines()
stopwords = [word.strip("#") for word in stopwords if word not in ["", " ", "\n"]]
stopwords_set = set(stopwords)  # Convert to set for faster lookup

with open('vocab.txt', 'r') as file:
    vocab = file.read().splitlines()
vocab = [word.lower().strip() for word in vocab if word not in ["", " ", "\n"]]
vocab_set = set(vocab)  # Convert to set for faster lookup
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### 2. Data Preprocessing

# %%
# Preprocessing functions

def clean_text(text):
    """Perform basic text cleaning and convert text to lowercase."""
    return text.lower()

def tokenize_and_filter(text, stopwords_set, vocab_set):
    """
    Tokenize the text using NLTK's word_tokenize, remove stopwords, and filter by vocab.
    """
    tokens = word_tokenize(text)
    filtered_tokens = [token for token in tokens if token not in stopwords_set and token in vocab_set]
    return filtered_tokens

def preprocess_text(text, stopwords_set, vocab_set):
    """
    Clean, tokenize, and filter the text based on stopwords and vocab.
    """
    cleaned_text = clean_text(text)
    filtered_tokens = tokenize_and_filter(cleaned_text, stopwords_set, vocab_set)
    return ' '.join(filtered_tokens)

# %%
# Apply Preprocessing to Datasets
train_df['cleaned_text'] = train_df['text'].apply(lambda x: preprocess_text(x, stopwords_set, vocab_set))
test_df['cleaned_text'] = test_df['text'].apply(lambda x: preprocess_text(x, stopwords_set, vocab_set))

# %%
# Prepare data for embedding

# Combine train and test data for the Word2Vec model to ensure it's trained on all the data
combined_text = list(train_df['cleaned_text']) + list(test_df['cleaned_text'])
tokenized_data = [text.split() for text in combined_text]

# %%
# Train Word2Vec model

w2v_model = Word2Vec(sentences=tokenized_data, vector_size=300, window=5, min_count=1, workers=4)

def document_embedding(text, model):
    """Generate document embeddings by averaging word vectors."""
    words = text.split()
    words_in_vocab = [word for word in words if word in model.wv]
    if not words_in_vocab:
        return np.zeros(model.vector_size)
    embedding = np.mean([model.wv[word] for word in words_in_vocab], axis=0)
    return embedding

# Apply Document Embedding to DataFrame
train_df['embedding'] = train_df['cleaned_text'].apply(lambda x: document_embedding(x, w2v_model))
test_df['embedding'] = test_df['cleaned_text'].apply(lambda x: document_embedding(x, w2v_model))

# %% [markdown]
# ### 3. Prep Dataset for Learning

# %%
# Adjusting the labels to be zero-indexed since they start from 1
train_df['label'] = train_df['label'] - 1
test_df['label'] = test_df['label'] - 1

# %%
# Conversion of embeddings and labels to tensors
train_features = torch.tensor(train_df['embedding'].tolist())
train_labels = torch.tensor(train_df['label'].values)
test_features = torch.tensor(test_df['embedding'].tolist())
test_labels = torch.tensor(test_df['label'].values)

# Ensure tensors are of float type for features and long (int) for labels
train_features = train_features.float()
test_features = test_features.float()
train_labels = train_labels.long()
test_labels = test_labels.long()

# Create TensorDatasets
train_dataset = TensorDataset(train_features, train_labels)
test_dataset = TensorDataset(test_features, test_labels)

# Create DataLoaders for batching the data
batch_size = 128  # This can be adjusted
trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
testloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# <ipython-input-10-d266d1aa7e06>:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:275.)
#   train_features = torch.tensor(train_df['embedding'].tolist())

# %%
# Calculate class weights to handle slight class imbalance

# Counts for each class to calculate class weights
class_counts = torch.tensor([1442, 1126, 1040, 891], dtype=torch.float)

# Calculate class weights
total_count = class_counts.sum()
num_classes = len(class_counts)
class_weights = total_count / (num_classes * class_counts)

# If you're using a GPU, you might want to move the weights to the same device as your model and data
class_weights = class_weights.to('cuda' if torch.cuda.is_available() else 'cpu')

print("Class weights:", class_weights)
# Out:
# Class weights: tensor([0.7800, 0.9989, 1.0815, 1.2623])

# %% [markdown]
# ### 4. Build First Model: Plain Vanilla Neural Network

# %%
# Define the NN architecture
class SimpleNN(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64) # First layer
        self.fc2 = nn.Linear(64, 32)        # Second layer
        self.fc3 = nn.Linear(32, output_dim)# Output layer

    def forward(self, x):
        x = F.relu(self.fc1(x)) # Activation function for first layer
        x = F.relu(self.fc2(x)) # Activation function for second layer
        x = self.fc3(x)         # No activation for output layer in forward pass
        return x

# Initialize model, loss, and optimizer
nn_input_dim = 300    # Embedding dimension
nn_output_dim = 4     # Number of classes
nn_model = SimpleNN(nn_input_dim, nn_output_dim)
nn_criterion = nn.CrossEntropyLoss(weight = class_weights) # added class weights to the loss function
nn_optimizer = torch.optim.SGD(nn_model.parameters(), lr=0.02)

# %% [markdown]
# ### 5. Build the second Model: Recurrent Neural Network

# %%
class SimpleRNN(nn.Module):
    def __init__(self, input_dim, output_dim, hidden_dim, num_layers):
        super(SimpleRNN, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.rnn = nn.RNN(input_dim, hidden_dim, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Expecting x to be of shape [batch_size, seq_len, features]
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)
        out, _ = self.rnn(x, h0)
        out = self.fc(out[:, -1, :])  # Use the output of the last time step
        return out

# Initialize the RNN model
rnn_input_dim = 1   # Number of features per time step (adjusted for example)
rnn_hidden_dim = 64 # RNN hidden dimension
rnn_num_layers = 1  # Number of RNN layers
rnn_output_dim = 4  # Number of output classes
rnn_model = SimpleRNN(rnn_input_dim, rnn_output_dim, rnn_hidden_dim, rnn_num_layers)
rnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
#optimizer = optim.SGD(model.parameters(), lr=0.05)
rnn_optimizer = optim.Adam(rnn_model.parameters(), lr=0.005)

# %% [markdown]
# ### 6. Build the Third Model: Convolutional Neural Network

# %%
class SimpleCNN(nn.Module):
    def __init__(self, seq_len, input_dim, output_dim):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv1d(in_channels=seq_len, out_channels=64, kernel_size=3, stride=1, padding=1)
        # No pooling layer to avoid reducing sequence length to 0
        self.fc1 = nn.Linear(64 * input_dim, 64) # Adapt based on your actual input dimensions
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, output_dim)

    def forward(self, x):
        x = x.permute(0, 2, 1)  # Adjust to (batch, channels, length) for Conv1d
        x = F.relu(self.conv1(x))
        # No pooling here
        x = x.view(x.size(0), -1)  # Flatten
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Adjustments in model initialization
cnn_seq_len = 300  # Embedding dimension
cnn_input_dim = 1   # Assuming each sequence step has 1 dimension
cnn_output_dim = 4  # Number of output classes
cnn_model = SimpleCNN(cnn_seq_len, cnn_input_dim, cnn_output_dim)
cnn_criterion = nn.CrossEntropyLoss(weight=class_weights)
cnn_optimizer = torch.optim.SGD(cnn_model.parameters(), lr=0.01)

# %% [markdown]
# ### 6. Build the second Model: LSTM

# %%
class SimpleLSTM(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, output_dim, lstm_num_layers):
        super(SimpleLSTM, self).__init__()
        self.lstm_hidden_dim = lstm_hidden_dim
        self.lstm_num_layers = lstm_num_layers

        # LSTM layer
        self.lstm = nn.LSTM(input_dim, lstm_hidden_dim, lstm_num_layers, batch_first=True)

        # Fully connected layer
        self.fc1 = nn.Linear(lstm_hidden_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, output_dim)

    def forward(self, x):
        # Initialize hidden and cell states
        h0 = torch.zeros(self.lstm_num_layers, x.size(0), self.lstm_hidden_dim).to(x.device)
        c0 = torch.zeros(self.lstm_num_layers, x.size(0), self.lstm_hidden_dim).to(x.device)

        # Forward propagate the LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Take the output of the last time step
        out = out[:, -1, :]
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc3(out)
        return out

# Model initialization
lstm_input_dim = 1   # Number of features per time step
lstm_hidden_dim = 64 # Number of features in the hidden state
lstm_num_layers = 1  # Number of stacked LSTM layers
lstm_output_dim = 4  # Number of output classes
lstm_model = SimpleLSTM(lstm_input_dim, lstm_hidden_dim, lstm_output_dim, lstm_num_layers)
lstm_criterion = nn.CrossEntropyLoss(weight=class_weights)
lstm_optimizer = torch.optim.Adam(lstm_model.parameters(), lr=0.01)

# %% [markdown]
# ### 7. Run the Models

# %%
# Define usefull functions for running the models

def reshape_input_for_rnn(vectors):
    """Reshapes input vectors for RNN models."""
    return vectors.view(vectors.size(0), 300, 1)  # Adjust the reshape parameters as needed for your RNN

def add_channel_dimension(vectors):
    """Adds a channel dimension to the input vectors, required for CNN models."""
    return vectors.unsqueeze(1)  # Add a channel dimension

def ensure_input_shape_for_lstm(vectors):
    """Ensures input vectors are of shape (batch_size, seq_len, input_dim) for LSTM models."""
    return vectors.unsqueeze(-1)  # Add the necessary dimension



def plot_training_validation_loss_accuracy(training_losses, validation_losses, training_accuracies, validation_accuracies):
    """Plots the training and validation loss and accuracy."""
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(training_losses, label='Training Loss')
    plt.plot(validation_losses, label='Validation Loss')
    plt.title('Loss over time')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(training_accuracies, label='Training Accuracy')
    plt.plot(validation_accuracies, label='Validation Accuracy')
    plt.title('Accuracy over time')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()

    plt.tight_layout()
    plt.show()

def train_and_validate_model(model, trainloader, testloader, criterion, optimizer, epochs=100, input_transform=None):
    """
    Trains and validates the model, including an optional input transformation.

    Parameters:
    - model: The model to be trained and validated.
    - trainloader: DataLoader for training data.
    - testloader: DataLoader for test/validation data.
    - criterion: The loss function.
    - optimizer: The optimizer.
    - epochs: Number of epochs to train for.
    - input_transform: Optional function to transform input data (e.g., reshaping for RNN or adding a channel dimension for CNN).
    """
    training_losses = []
    validation_losses = []
    training_accuracies = []
    validation_accuracies = []

    for epoch in range(epochs):
        model.train()
        total_loss, total, correct = 0, 0, 0
        for vectors, targets in trainloader:
            if input_transform:
                vectors = input_transform(vectors)
            optimizer.zero_grad()
            outputs = model(vectors)
            loss = criterion(outputs, targets)
            total_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
            loss.backward()
            optimizer.step()

        training_losses.append(total_loss / len(trainloader))
        training_accuracies.append(100 * correct / total)

        model.eval()
        total_loss, total, correct = 0, 0, 0
        with torch.no_grad():
            for vectors, targets in testloader:
                if input_transform:
                    vectors = input_transform(vectors)
                outputs = model(vectors)
                loss = criterion(outputs, targets)
                total_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += targets.size(0)
                correct += (predicted == targets).sum().item()

        validation_losses.append(total_loss / len(testloader))
        validation_accuracies.append(100 * correct / total)

        print(f'Epoch {epoch+1}/{epochs}, Training Loss: {training_losses[-1]:.4f}, Training Accuracy: {training_accuracies[-1]:.2f}%, Validation Loss: {validation_losses[-1]:.4f}, Validation Accuracy: {validation_accuracies[-1]:.2f}%')

    return training_losses, validation_losses, training_accuracies, validation_accuracies

# %%
# Run and plot the results of the SimpleNN model
training_losses, validation_losses, training_accuracies, validation_accuracies = train_and_validate_model(
    model=nn_model,  # This can be cnn_model or lstm_model as well
    trainloader=trainloader,
    testloader=testloader,
    criterion=nn_criterion,
    optimizer=nn_optimizer,
    epochs=100
)

plot_training_validation_loss_accuracy(training_losses, validation_losses, training_accuracies, validation_accuracies)
# Out:
# Epoch 1/100, Training Loss: 1.3833, Training Accuracy: 19.80%, Validation Loss: 1.3798, Validation Accuracy: 18.20%
# Epoch 2/100, Training Loss: 1.3764, Training Accuracy: 21.56%, Validation Loss: 1.3714, Validation Accuracy: 25.80%
# Epoch 3/100, Training Loss: 1.3683, Training Accuracy: 34.72%, Validation Loss: 1.3617, Validation Accuracy: 45.60%
# Epoch 4/100, Training Loss: 1.3584, Training Accuracy: 47.25%, Validation Loss: 1.3495, Validation Accuracy: 51.40%
# Epoch 5/100, Training Loss: 1.3457, Training Accuracy: 50.99%, Validation Loss: 1.3334, Validation Accuracy: 53.40%
# Epoch 6/100, Training Loss: 1.3283, Training Accuracy: 51.74%, Validation Loss: 1.3123, Validation Accuracy: 54.00%
# Epoch 7/100, Training Loss: 1.3092, Training Accuracy: 51.94%, Validation Loss: 1.2883, Validation Accuracy: 53.80%
# Epoch 8/100, Training Loss: 1.2851, Training Accuracy: 52.14%, Validation Loss: 1.2602, Validation Accuracy: 53.80%
# Epoch 9/100, Training Loss: 1.2613, Training Accuracy: 52.17%, Validation Loss: 1.2339, Validation Accuracy: 53.60%
# Epoch 10/100, Training Loss: 1.2342, Training Accuracy: 52.34%, Validation Loss: 1.2081, Validation Accuracy: 53.20%
# Epoch 11/100, Training Loss: 1.2105, Training Accuracy: 52.23%, Validation Loss: 1.1874, Validation Accuracy: 53.40%
# Epoch 12/100, Training Loss: 1.1919, Training Accuracy: 52.08%, Validation Loss: 1.1702, Validation Accuracy: 53.40%
# Epoch 13/100, Training Loss: 1.1795, Training Accuracy: 52.10%, Validation Loss: 1.1593, Validation Accuracy: 52.60%
# Epoch 14/100, Training Loss: 1.1641, Training Accuracy: 52.17%, Validation Loss: 1.1498, Validation Accuracy: 52.00%
# Epoch 15/100, Training Loss: 1.1551, Training Accuracy: 52.26%, Validation Loss: 1.1387, Validation Accuracy: 53.00%
# Epoch 16/100, Training Loss: 1.1448, Training Accuracy: 52.28%, Validation Loss: 1.1306, Validation Accuracy: 53.40%
# Epoch 17/100, Training Loss: 1.1345, Training Accuracy: 52.14%, Validation Loss: 1.1204, Validation Accuracy: 53.40%
# Epoch 18/100, Training Loss: 1.1255, Training Accuracy: 51.97%, Validation Loss: 1.1104, Validation Accuracy: 52.80%
# Epoch 19/100, Training Loss: 1.1112, Training Accuracy: 51.94%, Validation Loss: 1.0984, Validation Accuracy: 52.40%
# Epoch 20/100, Training Loss: 1.1001, Training Accuracy: 52.12%, Validation Loss: 1.0861, Validation Accuracy: 51.60%
# Epoch 21/100, Training Loss: 1.0866, Training Accuracy: 52.08%, Validation Loss: 1.0707, Validation Accuracy: 51.40%
# Epoch 22/100, Training Loss: 1.0748, Training Accuracy: 52.17%, Validation Loss: 1.0602, Validation Accuracy: 50.80%
# Epoch 23/100, Training Loss: 1.0606, Training Accuracy: 52.32%, Validation Loss: 1.0455, Validation Accuracy: 50.40%
# Epoch 24/100, Training Loss: 1.0429, Training Accuracy: 52.52%, Validation Loss: 1.0291, Validation Accuracy: 51.20%
# Epoch 25/100, Training Loss: 1.0294, Training Accuracy: 52.43%, Validation Loss: 1.0208, Validation Accuracy: 50.20%
# Epoch 26/100, Training Loss: 1.0198, Training Accuracy: 52.43%, Validation Loss: 1.0092, Validation Accuracy: 51.20%
# Epoch 27/100, Training Loss: 1.0086, Training Accuracy: 52.59%, Validation Loss: 0.9973, Validation Accuracy: 52.20%
# Epoch 28/100, Training Loss: 1.0049, Training Accuracy: 52.50%, Validation Loss: 0.9923, Validation Accuracy: 52.20%
# Epoch 29/100, Training Loss: 0.9932, Training Accuracy: 52.63%, Validation Loss: 0.9788, Validation Accuracy: 52.80%
# Epoch 30/100, Training Loss: 0.9920, Training Accuracy: 52.75%, Validation Loss: 0.9856, Validation Accuracy: 51.20%
# Epoch 31/100, Training Loss: 0.9807, Training Accuracy: 52.63%, Validation Loss: 0.9713, Validation Accuracy: 51.60%
# Epoch 32/100, Training Loss: 0.9819, Training Accuracy: 52.75%, Validation Loss: 0.9661, Validation Accuracy: 53.40%
# Epoch 33/100, Training Loss: 0.9705, Training Accuracy: 52.68%, Validation Loss: 0.9688, Validation Accuracy: 53.20%
# Epoch 34/100, Training Loss: 0.9739, Training Accuracy: 52.81%, Validation Loss: 0.9631, Validation Accuracy: 52.60%
# Epoch 35/100, Training Loss: 0.9684, Training Accuracy: 52.99%, Validation Loss: 0.9663, Validation Accuracy: 51.80%
# Epoch 36/100, Training Loss: 0.9667, Training Accuracy: 52.79%, Validation Loss: 0.9564, Validation Accuracy: 53.00%
# Epoch 37/100, Training Loss: 0.9677, Training Accuracy: 53.10%, Validation Loss: 0.9563, Validation Accuracy: 52.80%
# Epoch 38/100, Training Loss: 0.9648, Training Accuracy: 53.19%, Validation Loss: 0.9459, Validation Accuracy: 54.20%
# Epoch 39/100, Training Loss: 0.9607, Training Accuracy: 53.57%, Validation Loss: 0.9458, Validation Accuracy: 53.60%
# Epoch 40/100, Training Loss: 0.9587, Training Accuracy: 53.32%, Validation Loss: 0.9422, Validation Accuracy: 53.60%
# Epoch 41/100, Training Loss: 0.9577, Training Accuracy: 53.39%, Validation Loss: 0.9413, Validation Accuracy: 53.80%
# Epoch 42/100, Training Loss: 0.9512, Training Accuracy: 53.50%, Validation Loss: 0.9419, Validation Accuracy: 53.20%
# Epoch 43/100, Training Loss: 0.9507, Training Accuracy: 53.59%, Validation Loss: 0.9368, Validation Accuracy: 53.60%
# Epoch 44/100, Training Loss: 0.9491, Training Accuracy: 53.66%, Validation Loss: 0.9397, Validation Accuracy: 53.80%
# Epoch 45/100, Training Loss: 0.9521, Training Accuracy: 53.46%, Validation Loss: 0.9288, Validation Accuracy: 53.60%
# Epoch 46/100, Training Loss: 0.9427, Training Accuracy: 53.63%, Validation Loss: 0.9325, Validation Accuracy: 53.80%
# Epoch 47/100, Training Loss: 0.9485, Training Accuracy: 53.46%, Validation Loss: 0.9266, Validation Accuracy: 54.40%
# Epoch 48/100, Training Loss: 0.9421, Training Accuracy: 53.63%, Validation Loss: 0.9304, Validation Accuracy: 53.40%
# Epoch 49/100, Training Loss: 0.9472, Training Accuracy: 53.63%, Validation Loss: 0.9260, Validation Accuracy: 54.00%
# Epoch 50/100, Training Loss: 0.9395, Training Accuracy: 53.12%, Validation Loss: 0.9241, Validation Accuracy: 54.60%
# Epoch 51/100, Training Loss: 0.9433, Training Accuracy: 53.41%, Validation Loss: 0.9219, Validation Accuracy: 54.00%
# Epoch 52/100, Training Loss: 0.9373, Training Accuracy: 53.70%, Validation Loss: 0.9213, Validation Accuracy: 54.20%
# Epoch 53/100, Training Loss: 0.9408, Training Accuracy: 53.50%, Validation Loss: 0.9301, Validation Accuracy: 54.20%
# Epoch 54/100, Training Loss: 0.9346, Training Accuracy: 53.61%, Validation Loss: 0.9211, Validation Accuracy: 54.80%
# Epoch 55/100, Training Loss: 0.9290, Training Accuracy: 53.88%, Validation Loss: 0.9268, Validation Accuracy: 53.20%
# Epoch 56/100, Training Loss: 0.9330, Training Accuracy: 53.79%, Validation Loss: 0.9240, Validation Accuracy: 54.20%
# Epoch 57/100, Training Loss: 0.9314, Training Accuracy: 53.61%, Validation Loss: 0.9186, Validation Accuracy: 54.20%
# Epoch 58/100, Training Loss: 0.9353, Training Accuracy: 53.46%, Validation Loss: 0.9142, Validation Accuracy: 55.00%
# Epoch 59/100, Training Loss: 0.9331, Training Accuracy: 53.99%, Validation Loss: 0.9147, Validation Accuracy: 55.00%
# Epoch 60/100, Training Loss: 0.9311, Training Accuracy: 53.92%, Validation Loss: 0.9188, Validation Accuracy: 53.40%
# Epoch 61/100, Training Loss: 0.9361, Training Accuracy: 53.77%, Validation Loss: 0.9124, Validation Accuracy: 54.40%
# Epoch 62/100, Training Loss: 0.9223, Training Accuracy: 54.19%, Validation Loss: 0.9148, Validation Accuracy: 53.40%
# Epoch 63/100, Training Loss: 0.9274, Training Accuracy: 53.90%, Validation Loss: 0.9117, Validation Accuracy: 54.40%
# Epoch 64/100, Training Loss: 0.9185, Training Accuracy: 54.06%, Validation Loss: 0.9104, Validation Accuracy: 54.40%
# Epoch 65/100, Training Loss: 0.9212, Training Accuracy: 53.92%, Validation Loss: 0.9192, Validation Accuracy: 52.80%
# Epoch 66/100, Training Loss: 0.9263, Training Accuracy: 53.75%, Validation Loss: 0.9034, Validation Accuracy: 55.80%
# Epoch 67/100, Training Loss: 0.9122, Training Accuracy: 54.10%, Validation Loss: 0.9012, Validation Accuracy: 55.40%
# Epoch 68/100, Training Loss: 0.9160, Training Accuracy: 54.06%, Validation Loss: 0.9093, Validation Accuracy: 53.80%
# Epoch 69/100, Training Loss: 0.9172, Training Accuracy: 53.68%, Validation Loss: 0.9017, Validation Accuracy: 54.60%
# Epoch 70/100, Training Loss: 0.9207, Training Accuracy: 53.95%, Validation Loss: 0.9048, Validation Accuracy: 54.40%
# Epoch 71/100, Training Loss: 0.9181, Training Accuracy: 53.86%, Validation Loss: 0.8966, Validation Accuracy: 55.40%
# Epoch 72/100, Training Loss: 0.9154, Training Accuracy: 54.10%, Validation Loss: 0.9006, Validation Accuracy: 54.60%
# Epoch 73/100, Training Loss: 0.9097, Training Accuracy: 54.57%, Validation Loss: 0.9022, Validation Accuracy: 54.80%
# Epoch 74/100, Training Loss: 0.9113, Training Accuracy: 54.57%, Validation Loss: 0.8971, Validation Accuracy: 53.80%
# Epoch 75/100, Training Loss: 0.9065, Training Accuracy: 54.26%, Validation Loss: 0.8955, Validation Accuracy: 55.00%
# Epoch 76/100, Training Loss: 0.9095, Training Accuracy: 54.41%, Validation Loss: 0.8948, Validation Accuracy: 54.60%
# Epoch 77/100, Training Loss: 0.9086, Training Accuracy: 54.35%, Validation Loss: 0.8992, Validation Accuracy: 54.20%
# Epoch 78/100, Training Loss: 0.9067, Training Accuracy: 54.48%, Validation Loss: 0.8892, Validation Accuracy: 55.40%
# Epoch 79/100, Training Loss: 0.9138, Training Accuracy: 54.50%, Validation Loss: 0.8949, Validation Accuracy: 54.60%
# Epoch 80/100, Training Loss: 0.9057, Training Accuracy: 54.57%, Validation Loss: 0.8886, Validation Accuracy: 54.20%
# Epoch 81/100, Training Loss: 0.9019, Training Accuracy: 54.77%, Validation Loss: 0.8926, Validation Accuracy: 53.80%
# Epoch 82/100, Training Loss: 0.9006, Training Accuracy: 55.03%, Validation Loss: 0.9040, Validation Accuracy: 53.00%
# Epoch 83/100, Training Loss: 0.9020, Training Accuracy: 54.50%, Validation Loss: 0.8890, Validation Accuracy: 55.00%
# Epoch 84/100, Training Loss: 0.9119, Training Accuracy: 54.75%, Validation Loss: 0.9001, Validation Accuracy: 55.20%
# Epoch 85/100, Training Loss: 0.8982, Training Accuracy: 54.08%, Validation Loss: 0.8848, Validation Accuracy: 53.80%
# Epoch 86/100, Training Loss: 0.8979, Training Accuracy: 55.10%, Validation Loss: 0.8928, Validation Accuracy: 53.60%
# Epoch 87/100, Training Loss: 0.9017, Training Accuracy: 54.66%, Validation Loss: 0.9077, Validation Accuracy: 52.20%
# Epoch 88/100, Training Loss: 0.9008, Training Accuracy: 54.68%, Validation Loss: 0.8920, Validation Accuracy: 53.80%
# Epoch 89/100, Training Loss: 0.8953, Training Accuracy: 54.66%, Validation Loss: 0.8838, Validation Accuracy: 54.60%
# Epoch 90/100, Training Loss: 0.8966, Training Accuracy: 54.90%, Validation Loss: 0.8818, Validation Accuracy: 54.80%
# Epoch 91/100, Training Loss: 0.8996, Training Accuracy: 55.30%, Validation Loss: 0.8859, Validation Accuracy: 54.40%
# Epoch 92/100, Training Loss: 0.8917, Training Accuracy: 55.01%, Validation Loss: 0.8863, Validation Accuracy: 54.40%
# Epoch 93/100, Training Loss: 0.8949, Training Accuracy: 54.86%, Validation Loss: 0.8856, Validation Accuracy: 54.80%
# Epoch 94/100, Training Loss: 0.8901, Training Accuracy: 54.95%, Validation Loss: 0.8839, Validation Accuracy: 54.60%
# Epoch 95/100, Training Loss: 0.8956, Training Accuracy: 54.83%, Validation Loss: 0.8880, Validation Accuracy: 53.60%
# Epoch 96/100, Training Loss: 0.8975, Training Accuracy: 55.21%, Validation Loss: 0.8837, Validation Accuracy: 54.40%
# Epoch 97/100, Training Loss: 0.8988, Training Accuracy: 55.37%, Validation Loss: 0.8824, Validation Accuracy: 54.80%
# Epoch 98/100, Training Loss: 0.8867, Training Accuracy: 55.12%, Validation Loss: 0.8795, Validation Accuracy: 53.40%
# Epoch 99/100, Training Loss: 0.8879, Training Accuracy: 55.52%, Validation Loss: 0.8775, Validation Accuracy: 53.60%
# Epoch 100/100, Training Loss: 0.8913, Training Accuracy: 55.15%, Validation Loss: 0.8922, Validation Accuracy: 53.40%

# %%
# Run and plot the results of the RNN model
training_losses, validation_losses, training_accuracies, validation_accuracies = train_and_validate_model(
    model=rnn_model,
    trainloader=trainloader,
    testloader=testloader,
    criterion=rnn_criterion,
    optimizer=rnn_optimizer,
    epochs=100,
    input_transform=reshape_input_for_rnn  # Ensure this matches your RNN's expected input shape
)

plot_training_validation_loss_accuracy(training_losses, validation_losses, training_accuracies, validation_accuracies)
# Out:
# Epoch 1/100, Training Loss: 1.4226, Training Accuracy: 27.92%, Validation Loss: 1.4020, Validation Accuracy: 25.00%
# Epoch 2/100, Training Loss: 1.3865, Training Accuracy: 29.85%, Validation Loss: 1.3696, Validation Accuracy: 25.20%
# Epoch 3/100, Training Loss: 1.3505, Training Accuracy: 35.99%, Validation Loss: 1.3066, Validation Accuracy: 47.20%
# Epoch 4/100, Training Loss: 1.2913, Training Accuracy: 42.79%, Validation Loss: 1.2836, Validation Accuracy: 37.80%
# Epoch 5/100, Training Loss: 1.2371, Training Accuracy: 42.88%, Validation Loss: 1.1681, Validation Accuracy: 52.60%
# Epoch 6/100, Training Loss: 1.3324, Training Accuracy: 33.36%, Validation Loss: 1.3489, Validation Accuracy: 33.60%
# Epoch 7/100, Training Loss: 1.3898, Training Accuracy: 29.01%, Validation Loss: 1.4222, Validation Accuracy: 18.20%
# Epoch 8/100, Training Loss: 1.3931, Training Accuracy: 30.32%, Validation Loss: 1.3196, Validation Accuracy: 21.60%
# Epoch 9/100, Training Loss: 1.3455, Training Accuracy: 36.12%, Validation Loss: 1.3154, Validation Accuracy: 40.80%
# Epoch 10/100, Training Loss: 1.3011, Training Accuracy: 39.99%, Validation Loss: 1.2667, Validation Accuracy: 37.40%
# Epoch 11/100, Training Loss: 1.2683, Training Accuracy: 41.56%, Validation Loss: 1.2191, Validation Accuracy: 48.40%
# Epoch 12/100, Training Loss: 1.2513, Training Accuracy: 41.16%, Validation Loss: 1.1833, Validation Accuracy: 47.40%
# Epoch 13/100, Training Loss: 1.2280, Training Accuracy: 43.41%, Validation Loss: 1.1756, Validation Accuracy: 46.20%
# Epoch 14/100, Training Loss: 1.2104, Training Accuracy: 44.01%, Validation Loss: 1.1865, Validation Accuracy: 47.60%
# Epoch 15/100, Training Loss: 1.2022, Training Accuracy: 44.63%, Validation Loss: 1.1540, Validation Accuracy: 50.40%
# Epoch 16/100, Training Loss: 1.1900, Training Accuracy: 45.52%, Validation Loss: 1.1470, Validation Accuracy: 51.40%
# Epoch 17/100, Training Loss: 1.1791, Training Accuracy: 47.34%, Validation Loss: 1.1311, Validation Accuracy: 49.80%
# Epoch 18/100, Training Loss: 1.1659, Training Accuracy: 47.88%, Validation Loss: 1.1244, Validation Accuracy: 50.40%
# Epoch 19/100, Training Loss: 1.1848, Training Accuracy: 44.39%, Validation Loss: 1.1520, Validation Accuracy: 47.60%
# Epoch 20/100, Training Loss: 1.1649, Training Accuracy: 48.52%, Validation Loss: 1.1423, Validation Accuracy: 50.20%
# Epoch 21/100, Training Loss: 1.1661, Training Accuracy: 46.92%, Validation Loss: 1.1223, Validation Accuracy: 49.80%
# Epoch 22/100, Training Loss: 1.1547, Training Accuracy: 48.23%, Validation Loss: 1.1716, Validation Accuracy: 44.20%
# Epoch 23/100, Training Loss: 1.1541, Training Accuracy: 47.34%, Validation Loss: 1.1234, Validation Accuracy: 51.20%
# Epoch 24/100, Training Loss: 1.1378, Training Accuracy: 49.86%, Validation Loss: 1.1211, Validation Accuracy: 52.00%
# Epoch 25/100, Training Loss: 1.1358, Training Accuracy: 49.43%, Validation Loss: 1.1054, Validation Accuracy: 52.00%
# Epoch 26/100, Training Loss: 1.1430, Training Accuracy: 49.26%, Validation Loss: 1.1256, Validation Accuracy: 51.00%
# Epoch 27/100, Training Loss: 1.1575, Training Accuracy: 48.01%, Validation Loss: 1.1463, Validation Accuracy: 48.20%
# Epoch 28/100, Training Loss: 1.1431, Training Accuracy: 48.30%, Validation Loss: 1.1475, Validation Accuracy: 51.00%
# Epoch 29/100, Training Loss: 1.2516, Training Accuracy: 41.96%, Validation Loss: 1.3948, Validation Accuracy: 42.40%
# Epoch 30/100, Training Loss: 1.3884, Training Accuracy: 30.03%, Validation Loss: 1.2958, Validation Accuracy: 44.60%
# Epoch 31/100, Training Loss: 1.3230, Training Accuracy: 38.48%, Validation Loss: 1.2871, Validation Accuracy: 44.00%
# Epoch 32/100, Training Loss: 1.3118, Training Accuracy: 38.45%, Validation Loss: 1.2962, Validation Accuracy: 46.00%
# Epoch 33/100, Training Loss: 1.2983, Training Accuracy: 41.45%, Validation Loss: 1.2579, Validation Accuracy: 44.20%
# Epoch 34/100, Training Loss: 1.2570, Training Accuracy: 41.65%, Validation Loss: 1.2184, Validation Accuracy: 46.00%
# Epoch 35/100, Training Loss: 1.2369, Training Accuracy: 42.41%, Validation Loss: 1.2173, Validation Accuracy: 46.80%
# Epoch 36/100, Training Loss: 1.2225, Training Accuracy: 42.61%, Validation Loss: 1.1983, Validation Accuracy: 46.40%
# Epoch 37/100, Training Loss: 1.2155, Training Accuracy: 42.97%, Validation Loss: 1.2174, Validation Accuracy: 42.80%
# Epoch 38/100, Training Loss: 1.2170, Training Accuracy: 43.37%, Validation Loss: 1.2123, Validation Accuracy: 46.20%
# Epoch 39/100, Training Loss: 1.2246, Training Accuracy: 42.30%, Validation Loss: 1.2210, Validation Accuracy: 43.80%
# Epoch 40/100, Training Loss: 1.2255, Training Accuracy: 43.48%, Validation Loss: 1.6222, Validation Accuracy: 23.60%
# Epoch 41/100, Training Loss: 1.3797, Training Accuracy: 31.43%, Validation Loss: 1.3057, Validation Accuracy: 42.20%
# Epoch 42/100, Training Loss: 1.3106, Training Accuracy: 35.87%, Validation Loss: 1.2748, Validation Accuracy: 42.00%
# Epoch 43/100, Training Loss: 1.2996, Training Accuracy: 36.34%, Validation Loss: 1.2674, Validation Accuracy: 41.00%
# Epoch 44/100, Training Loss: 1.3135, Training Accuracy: 34.34%, Validation Loss: 1.3000, Validation Accuracy: 35.40%
# Epoch 45/100, Training Loss: 1.2911, Training Accuracy: 38.28%, Validation Loss: 1.2722, Validation Accuracy: 42.80%
# Epoch 46/100, Training Loss: 1.2955, Training Accuracy: 36.63%, Validation Loss: 1.2669, Validation Accuracy: 41.80%
# Epoch 47/100, Training Loss: 1.2906, Training Accuracy: 38.08%, Validation Loss: 1.2579, Validation Accuracy: 41.80%
# Epoch 48/100, Training Loss: 1.2927, Training Accuracy: 38.28%, Validation Loss: 1.2647, Validation Accuracy: 35.40%
# Epoch 49/100, Training Loss: 1.2977, Training Accuracy: 37.59%, Validation Loss: 1.2740, Validation Accuracy: 34.60%
# Epoch 50/100, Training Loss: 1.2885, Training Accuracy: 37.01%, Validation Loss: 1.2617, Validation Accuracy: 41.60%
# Epoch 51/100, Training Loss: 1.2949, Training Accuracy: 37.19%, Validation Loss: 1.2755, Validation Accuracy: 39.20%
# Epoch 52/100, Training Loss: 1.2981, Training Accuracy: 37.59%, Validation Loss: 1.2920, Validation Accuracy: 34.20%
# Epoch 53/100, Training Loss: 1.2956, Training Accuracy: 36.19%, Validation Loss: 1.2739, Validation Accuracy: 33.40%
# Epoch 54/100, Training Loss: 1.2913, Training Accuracy: 38.70%, Validation Loss: 1.2679, Validation Accuracy: 36.80%
# Epoch 55/100, Training Loss: 1.2926, Training Accuracy: 35.94%, Validation Loss: 1.2797, Validation Accuracy: 36.00%
# Epoch 56/100, Training Loss: 1.2856, Training Accuracy: 39.12%, Validation Loss: 1.2687, Validation Accuracy: 34.80%
# Epoch 57/100, Training Loss: 1.2807, Training Accuracy: 38.05%, Validation Loss: 1.2664, Validation Accuracy: 40.40%
# Epoch 58/100, Training Loss: 1.2814, Training Accuracy: 38.28%, Validation Loss: 1.2819, Validation Accuracy: 39.40%
# Epoch 59/100, Training Loss: 1.2792, Training Accuracy: 38.52%, Validation Loss: 1.2741, Validation Accuracy: 32.20%
# Epoch 60/100, Training Loss: 1.2806, Training Accuracy: 37.50%, Validation Loss: 1.2709, Validation Accuracy: 38.00%
# Epoch 61/100, Training Loss: 1.2782, Training Accuracy: 38.34%, Validation Loss: 1.2679, Validation Accuracy: 32.80%
# Epoch 62/100, Training Loss: 1.2675, Training Accuracy: 39.81%, Validation Loss: 1.2597, Validation Accuracy: 38.20%
# Epoch 63/100, Training Loss: 1.2707, Training Accuracy: 39.54%, Validation Loss: 1.2477, Validation Accuracy: 38.40%
# Epoch 64/100, Training Loss: 1.2712, Training Accuracy: 38.39%, Validation Loss: 1.2352, Validation Accuracy: 42.00%
# Epoch 65/100, Training Loss: 1.2588, Training Accuracy: 40.10%, Validation Loss: 1.2303, Validation Accuracy: 41.00%
# Epoch 66/100, Training Loss: 1.2543, Training Accuracy: 39.54%, Validation Loss: 1.2506, Validation Accuracy: 39.80%
# Epoch 67/100, Training Loss: 1.2498, Training Accuracy: 40.63%, Validation Loss: 1.2143, Validation Accuracy: 45.20%
# Epoch 68/100, Training Loss: 1.2435, Training Accuracy: 43.12%, Validation Loss: 1.2141, Validation Accuracy: 42.60%
# Epoch 69/100, Training Loss: 1.2401, Training Accuracy: 41.50%, Validation Loss: 1.2175, Validation Accuracy: 41.60%
# Epoch 70/100, Training Loss: 1.2261, Training Accuracy: 43.65%, Validation Loss: 1.2105, Validation Accuracy: 49.00%
# Epoch 71/100, Training Loss: 1.2308, Training Accuracy: 44.57%, Validation Loss: 1.2073, Validation Accuracy: 47.00%
# Epoch 72/100, Training Loss: 1.2190, Training Accuracy: 44.25%, Validation Loss: 1.2013, Validation Accuracy: 44.60%
# Epoch 73/100, Training Loss: 1.2185, Training Accuracy: 44.77%, Validation Loss: 1.1789, Validation Accuracy: 45.60%
# Epoch 74/100, Training Loss: 1.1971, Training Accuracy: 45.94%, Validation Loss: 1.1934, Validation Accuracy: 45.40%
# Epoch 75/100, Training Loss: 1.1921, Training Accuracy: 47.45%, Validation Loss: 1.1818, Validation Accuracy: 51.40%
# Epoch 76/100, Training Loss: 1.1912, Training Accuracy: 46.59%, Validation Loss: 1.1828, Validation Accuracy: 49.60%
# Epoch 77/100, Training Loss: 1.1885, Training Accuracy: 47.94%, Validation Loss: 1.1529, Validation Accuracy: 49.20%
# Epoch 78/100, Training Loss: 1.1835, Training Accuracy: 48.21%, Validation Loss: 1.1403, Validation Accuracy: 49.40%
# Epoch 79/100, Training Loss: 1.1984, Training Accuracy: 47.97%, Validation Loss: 1.1508, Validation Accuracy: 50.20%
# Epoch 80/100, Training Loss: 1.1746, Training Accuracy: 48.41%, Validation Loss: 1.1619, Validation Accuracy: 47.60%
# Epoch 81/100, Training Loss: 1.1715, Training Accuracy: 47.86%, Validation Loss: 1.1222, Validation Accuracy: 52.20%
# Epoch 82/100, Training Loss: 1.1672, Training Accuracy: 47.41%, Validation Loss: 1.1253, Validation Accuracy: 53.80%
# Epoch 83/100, Training Loss: 1.1794, Training Accuracy: 47.43%, Validation Loss: 1.1320, Validation Accuracy: 52.40%
# Epoch 84/100, Training Loss: 1.1627, Training Accuracy: 47.66%, Validation Loss: 1.1514, Validation Accuracy: 52.00%
# Epoch 85/100, Training Loss: 1.1547, Training Accuracy: 48.34%, Validation Loss: 1.1353, Validation Accuracy: 50.00%
# Epoch 86/100, Training Loss: 1.1432, Training Accuracy: 49.90%, Validation Loss: 1.1332, Validation Accuracy: 51.60%
# Epoch 87/100, Training Loss: 1.1501, Training Accuracy: 48.17%, Validation Loss: 1.1484, Validation Accuracy: 50.00%
# Epoch 88/100, Training Loss: 1.1554, Training Accuracy: 48.21%, Validation Loss: 1.1381, Validation Accuracy: 49.20%
# Epoch 89/100, Training Loss: 1.1399, Training Accuracy: 49.52%, Validation Loss: 1.1389, Validation Accuracy: 44.60%
# Epoch 90/100, Training Loss: 1.1379, Training Accuracy: 48.46%, Validation Loss: 1.1067, Validation Accuracy: 51.60%
# Epoch 91/100, Training Loss: 1.1413, Training Accuracy: 48.70%, Validation Loss: 1.1270, Validation Accuracy: 51.40%
# Epoch 92/100, Training Loss: 1.1326, Training Accuracy: 48.83%, Validation Loss: 1.1771, Validation Accuracy: 39.40%
# Epoch 93/100, Training Loss: 1.1331, Training Accuracy: 47.41%, Validation Loss: 1.1088, Validation Accuracy: 52.60%
# Epoch 94/100, Training Loss: 1.1364, Training Accuracy: 47.83%, Validation Loss: 1.0961, Validation Accuracy: 50.40%
# Epoch 95/100, Training Loss: 1.1224, Training Accuracy: 49.08%, Validation Loss: 1.1213, Validation Accuracy: 49.00%
# Epoch 96/100, Training Loss: 1.1145, Training Accuracy: 48.17%, Validation Loss: 1.1346, Validation Accuracy: 45.80%
# Epoch 97/100, Training Loss: 1.1285, Training Accuracy: 48.43%, Validation Loss: 1.0977, Validation Accuracy: 50.20%
# Epoch 98/100, Training Loss: 1.1193, Training Accuracy: 48.94%, Validation Loss: 1.1556, Validation Accuracy: 42.00%
# Epoch 99/100, Training Loss: 1.1302, Training Accuracy: 48.52%, Validation Loss: 1.0866, Validation Accuracy: 51.20%
# Epoch 100/100, Training Loss: 1.1209, Training Accuracy: 49.61%, Validation Loss: 1.1157, Validation Accuracy: 47.00%

# %%
# Run and plot the results of the CNN model
training_losses, validation_losses, training_accuracies, validation_accuracies = train_and_validate_model(
    model=cnn_model,
    trainloader=trainloader,
    testloader=testloader,
    criterion=cnn_criterion,
    optimizer=cnn_optimizer,
    epochs=100,
    input_transform=add_channel_dimension  # This function will add the necessary channel dimension for CNN inputs
)

# Plotting the results
plot_training_validation_loss_accuracy(training_losses, validation_losses, training_accuracies, validation_accuracies)
# Out:
# Epoch 1/100, Training Loss: 1.3893, Training Accuracy: 32.05%, Validation Loss: 1.3814, Validation Accuracy: 39.60%
# Epoch 2/100, Training Loss: 1.3887, Training Accuracy: 32.05%, Validation Loss: 1.3810, Validation Accuracy: 39.60%
# Epoch 3/100, Training Loss: 1.3871, Training Accuracy: 32.05%, Validation Loss: 1.3811, Validation Accuracy: 39.60%
# Epoch 4/100, Training Loss: 1.3872, Training Accuracy: 32.05%, Validation Loss: 1.3809, Validation Accuracy: 39.60%
# Epoch 5/100, Training Loss: 1.3859, Training Accuracy: 32.05%, Validation Loss: 1.3807, Validation Accuracy: 39.60%
# Epoch 6/100, Training Loss: 1.3852, Training Accuracy: 32.05%, Validation Loss: 1.3804, Validation Accuracy: 39.60%
# Epoch 7/100, Training Loss: 1.3844, Training Accuracy: 32.05%, Validation Loss: 1.3801, Validation Accuracy: 39.60%
# Epoch 8/100, Training Loss: 1.3843, Training Accuracy: 32.05%, Validation Loss: 1.3800, Validation Accuracy: 39.60%
# Epoch 9/100, Training Loss: 1.3839, Training Accuracy: 32.05%, Validation Loss: 1.3797, Validation Accuracy: 39.60%
# Epoch 10/100, Training Loss: 1.3828, Training Accuracy: 32.07%, Validation Loss: 1.3795, Validation Accuracy: 39.80%
# Epoch 11/100, Training Loss: 1.3821, Training Accuracy: 32.61%, Validation Loss: 1.3789, Validation Accuracy: 39.80%
# Epoch 12/100, Training Loss: 1.3814, Training Accuracy: 34.01%, Validation Loss: 1.3784, Validation Accuracy: 42.00%
# Epoch 13/100, Training Loss: 1.3809, Training Accuracy: 36.23%, Validation Loss: 1.3780, Validation Accuracy: 46.80%
# Epoch 14/100, Training Loss: 1.3802, Training Accuracy: 43.70%, Validation Loss: 1.3775, Validation Accuracy: 49.60%
# Epoch 15/100, Training Loss: 1.3796, Training Accuracy: 48.99%, Validation Loss: 1.3770, Validation Accuracy: 52.80%
# Epoch 16/100, Training Loss: 1.3786, Training Accuracy: 50.68%, Validation Loss: 1.3763, Validation Accuracy: 53.20%
# Epoch 17/100, Training Loss: 1.3772, Training Accuracy: 50.81%, Validation Loss: 1.3753, Validation Accuracy: 53.40%
# Epoch 18/100, Training Loss: 1.3762, Training Accuracy: 51.21%, Validation Loss: 1.3742, Validation Accuracy: 53.20%
# Epoch 19/100, Training Loss: 1.3752, Training Accuracy: 51.26%, Validation Loss: 1.3731, Validation Accuracy: 53.00%
# Epoch 20/100, Training Loss: 1.3739, Training Accuracy: 51.74%, Validation Loss: 1.3717, Validation Accuracy: 53.00%
# Epoch 21/100, Training Loss: 1.3721, Training Accuracy: 51.54%, Validation Loss: 1.3701, Validation Accuracy: 53.00%
# Epoch 22/100, Training Loss: 1.3704, Training Accuracy: 51.88%, Validation Loss: 1.3683, Validation Accuracy: 52.60%
# Epoch 23/100, Training Loss: 1.3680, Training Accuracy: 51.99%, Validation Loss: 1.3662, Validation Accuracy: 52.20%
# Epoch 24/100, Training Loss: 1.3659, Training Accuracy: 52.12%, Validation Loss: 1.3637, Validation Accuracy: 52.40%
# Epoch 25/100, Training Loss: 1.3627, Training Accuracy: 52.14%, Validation Loss: 1.3607, Validation Accuracy: 52.40%
# Epoch 26/100, Training Loss: 1.3597, Training Accuracy: 51.90%, Validation Loss: 1.3573, Validation Accuracy: 53.00%
# Epoch 27/100, Training Loss: 1.3560, Training Accuracy: 51.97%, Validation Loss: 1.3537, Validation Accuracy: 53.00%
# Epoch 28/100, Training Loss: 1.3523, Training Accuracy: 51.97%, Validation Loss: 1.3497, Validation Accuracy: 52.80%
# Epoch 29/100, Training Loss: 1.3476, Training Accuracy: 52.30%, Validation Loss: 1.3452, Validation Accuracy: 52.80%
# Epoch 30/100, Training Loss: 1.3425, Training Accuracy: 52.08%, Validation Loss: 1.3399, Validation Accuracy: 52.80%
# Epoch 31/100, Training Loss: 1.3375, Training Accuracy: 52.30%, Validation Loss: 1.3339, Validation Accuracy: 52.40%
# Epoch 32/100, Training Loss: 1.3302, Training Accuracy: 52.23%, Validation Loss: 1.3273, Validation Accuracy: 52.80%
# Epoch 33/100, Training Loss: 1.3231, Training Accuracy: 52.23%, Validation Loss: 1.3194, Validation Accuracy: 53.00%
# Epoch 34/100, Training Loss: 1.3138, Training Accuracy: 52.26%, Validation Loss: 1.3102, Validation Accuracy: 53.20%
# Epoch 35/100, Training Loss: 1.3039, Training Accuracy: 52.32%, Validation Loss: 1.3001, Validation Accuracy: 53.20%
# Epoch 36/100, Training Loss: 1.2936, Training Accuracy: 52.23%, Validation Loss: 1.2889, Validation Accuracy: 53.20%
# Epoch 37/100, Training Loss: 1.2825, Training Accuracy: 52.32%, Validation Loss: 1.2767, Validation Accuracy: 53.20%
# Epoch 38/100, Training Loss: 1.2688, Training Accuracy: 52.32%, Validation Loss: 1.2632, Validation Accuracy: 53.00%
# Epoch 39/100, Training Loss: 1.2572, Training Accuracy: 52.19%, Validation Loss: 1.2493, Validation Accuracy: 52.80%
# Epoch 40/100, Training Loss: 1.2452, Training Accuracy: 52.14%, Validation Loss: 1.2356, Validation Accuracy: 52.80%
# Epoch 41/100, Training Loss: 1.2319, Training Accuracy: 52.21%, Validation Loss: 1.2221, Validation Accuracy: 52.80%
# Epoch 42/100, Training Loss: 1.2191, Training Accuracy: 52.23%, Validation Loss: 1.2096, Validation Accuracy: 53.00%
# Epoch 43/100, Training Loss: 1.2061, Training Accuracy: 52.32%, Validation Loss: 1.1980, Validation Accuracy: 53.00%
# Epoch 44/100, Training Loss: 1.1982, Training Accuracy: 52.21%, Validation Loss: 1.1878, Validation Accuracy: 53.40%
# Epoch 45/100, Training Loss: 1.1857, Training Accuracy: 52.03%, Validation Loss: 1.1791, Validation Accuracy: 53.40%
# Epoch 46/100, Training Loss: 1.1825, Training Accuracy: 52.01%, Validation Loss: 1.1715, Validation Accuracy: 53.60%
# Epoch 47/100, Training Loss: 1.1756, Training Accuracy: 52.10%, Validation Loss: 1.1658, Validation Accuracy: 53.20%
# Epoch 48/100, Training Loss: 1.1720, Training Accuracy: 51.83%, Validation Loss: 1.1606, Validation Accuracy: 53.40%
# Epoch 49/100, Training Loss: 1.1698, Training Accuracy: 51.88%, Validation Loss: 1.1571, Validation Accuracy: 53.40%
# Epoch 50/100, Training Loss: 1.1611, Training Accuracy: 51.97%, Validation Loss: 1.1537, Validation Accuracy: 53.20%
# Epoch 51/100, Training Loss: 1.1576, Training Accuracy: 51.77%, Validation Loss: 1.1502, Validation Accuracy: 53.20%
# Epoch 52/100, Training Loss: 1.1571, Training Accuracy: 51.81%, Validation Loss: 1.1477, Validation Accuracy: 53.20%
# Epoch 53/100, Training Loss: 1.1525, Training Accuracy: 51.94%, Validation Loss: 1.1448, Validation Accuracy: 53.20%
# Epoch 54/100, Training Loss: 1.1496, Training Accuracy: 51.86%, Validation Loss: 1.1417, Validation Accuracy: 53.60%
# Epoch 55/100, Training Loss: 1.1479, Training Accuracy: 52.10%, Validation Loss: 1.1396, Validation Accuracy: 53.40%
# Epoch 56/100, Training Loss: 1.1450, Training Accuracy: 52.10%, Validation Loss: 1.1378, Validation Accuracy: 53.40%
# Epoch 57/100, Training Loss: 1.1468, Training Accuracy: 51.99%, Validation Loss: 1.1350, Validation Accuracy: 53.60%
# Epoch 58/100, Training Loss: 1.1411, Training Accuracy: 51.94%, Validation Loss: 1.1336, Validation Accuracy: 54.20%
# Epoch 59/100, Training Loss: 1.1466, Training Accuracy: 51.94%, Validation Loss: 1.1314, Validation Accuracy: 54.00%
# Epoch 60/100, Training Loss: 1.1397, Training Accuracy: 51.97%, Validation Loss: 1.1287, Validation Accuracy: 54.40%
# Epoch 61/100, Training Loss: 1.1383, Training Accuracy: 51.94%, Validation Loss: 1.1272, Validation Accuracy: 54.20%
# Epoch 62/100, Training Loss: 1.1365, Training Accuracy: 52.12%, Validation Loss: 1.1254, Validation Accuracy: 54.00%
# Epoch 63/100, Training Loss: 1.1309, Training Accuracy: 52.19%, Validation Loss: 1.1242, Validation Accuracy: 53.40%
# Epoch 64/100, Training Loss: 1.1320, Training Accuracy: 52.17%, Validation Loss: 1.1206, Validation Accuracy: 54.40%
# Epoch 65/100, Training Loss: 1.1269, Training Accuracy: 52.14%, Validation Loss: 1.1188, Validation Accuracy: 54.20%
# Epoch 66/100, Training Loss: 1.1262, Training Accuracy: 52.10%, Validation Loss: 1.1176, Validation Accuracy: 53.20%
# Epoch 67/100, Training Loss: 1.1231, Training Accuracy: 52.32%, Validation Loss: 1.1133, Validation Accuracy: 54.00%
# Epoch 68/100, Training Loss: 1.1250, Training Accuracy: 52.12%, Validation Loss: 1.1110, Validation Accuracy: 53.80%
# Epoch 69/100, Training Loss: 1.1220, Training Accuracy: 52.23%, Validation Loss: 1.1081, Validation Accuracy: 54.00%
# Epoch 70/100, Training Loss: 1.1201, Training Accuracy: 52.21%, Validation Loss: 1.1049, Validation Accuracy: 54.20%
# Epoch 71/100, Training Loss: 1.1130, Training Accuracy: 52.30%, Validation Loss: 1.1018, Validation Accuracy: 54.00%
# Epoch 72/100, Training Loss: 1.1085, Training Accuracy: 52.28%, Validation Loss: 1.0983, Validation Accuracy: 54.00%
# Epoch 73/100, Training Loss: 1.1060, Training Accuracy: 52.39%, Validation Loss: 1.0944, Validation Accuracy: 54.00%
# Epoch 74/100, Training Loss: 1.1026, Training Accuracy: 52.43%, Validation Loss: 1.0898, Validation Accuracy: 54.00%
# Epoch 75/100, Training Loss: 1.0975, Training Accuracy: 52.41%, Validation Loss: 1.0855, Validation Accuracy: 54.20%
# Epoch 76/100, Training Loss: 1.0939, Training Accuracy: 52.37%, Validation Loss: 1.0801, Validation Accuracy: 54.20%
# Epoch 77/100, Training Loss: 1.0870, Training Accuracy: 52.17%, Validation Loss: 1.0758, Validation Accuracy: 54.40%
# Epoch 78/100, Training Loss: 1.0832, Training Accuracy: 52.34%, Validation Loss: 1.0691, Validation Accuracy: 54.20%
# Epoch 79/100, Training Loss: 1.0790, Training Accuracy: 52.10%, Validation Loss: 1.0620, Validation Accuracy: 53.40%
# Epoch 80/100, Training Loss: 1.0717, Training Accuracy: 52.32%, Validation Loss: 1.0560, Validation Accuracy: 53.20%
# Epoch 81/100, Training Loss: 1.0659, Training Accuracy: 52.43%, Validation Loss: 1.0475, Validation Accuracy: 53.60%
# Epoch 82/100, Training Loss: 1.0552, Training Accuracy: 52.28%, Validation Loss: 1.0391, Validation Accuracy: 54.60%
# Epoch 83/100, Training Loss: 1.0502, Training Accuracy: 52.28%, Validation Loss: 1.0323, Validation Accuracy: 53.40%
# Epoch 84/100, Training Loss: 1.0407, Training Accuracy: 52.30%, Validation Loss: 1.0263, Validation Accuracy: 53.40%
# Epoch 85/100, Training Loss: 1.0308, Training Accuracy: 52.30%, Validation Loss: 1.0170, Validation Accuracy: 53.00%
# Epoch 86/100, Training Loss: 1.0262, Training Accuracy: 52.52%, Validation Loss: 1.0070, Validation Accuracy: 54.00%
# Epoch 87/100, Training Loss: 1.0153, Training Accuracy: 52.68%, Validation Loss: 1.0001, Validation Accuracy: 52.80%
# Epoch 88/100, Training Loss: 1.0103, Training Accuracy: 52.63%, Validation Loss: 0.9911, Validation Accuracy: 53.80%
# Epoch 89/100, Training Loss: 1.0022, Training Accuracy: 53.12%, Validation Loss: 0.9868, Validation Accuracy: 52.60%
# Epoch 90/100, Training Loss: 0.9966, Training Accuracy: 53.10%, Validation Loss: 0.9803, Validation Accuracy: 53.80%
# Epoch 91/100, Training Loss: 0.9926, Training Accuracy: 53.26%, Validation Loss: 0.9757, Validation Accuracy: 55.00%
# Epoch 92/100, Training Loss: 0.9814, Training Accuracy: 53.50%, Validation Loss: 0.9712, Validation Accuracy: 54.00%
# Epoch 93/100, Training Loss: 0.9761, Training Accuracy: 53.50%, Validation Loss: 0.9644, Validation Accuracy: 54.00%
# Epoch 94/100, Training Loss: 0.9732, Training Accuracy: 53.37%, Validation Loss: 0.9611, Validation Accuracy: 54.60%
# Epoch 95/100, Training Loss: 0.9714, Training Accuracy: 53.35%, Validation Loss: 0.9561, Validation Accuracy: 54.20%
# Epoch 96/100, Training Loss: 0.9751, Training Accuracy: 53.52%, Validation Loss: 0.9553, Validation Accuracy: 54.60%
# Epoch 97/100, Training Loss: 0.9652, Training Accuracy: 53.41%, Validation Loss: 0.9496, Validation Accuracy: 55.40%
# Epoch 98/100, Training Loss: 0.9615, Training Accuracy: 53.72%, Validation Loss: 0.9494, Validation Accuracy: 54.40%
# Epoch 99/100, Training Loss: 0.9629, Training Accuracy: 53.12%, Validation Loss: 0.9448, Validation Accuracy: 54.80%
# Epoch 100/100, Training Loss: 0.9648, Training Accuracy: 53.23%, Validation Loss: 0.9420, Validation Accuracy: 54.80%

# %%
# Run and plot the results of the LSTM model
training_losses, validation_losses, training_accuracies, validation_accuracies = train_and_validate_model(
    model=lstm_model,
    trainloader=trainloader,
    testloader=testloader,
    criterion=lstm_criterion,
    optimizer=lstm_optimizer,
    epochs=100,
    input_transform=ensure_input_shape_for_lstm  # Specific to LSTM model requirements
)

# Plotting the results for LSTM
plot_training_validation_loss_accuracy(training_losses, validation_losses, training_accuracies, validation_accuracies)
# Out:
# Epoch 1/100, Training Loss: 1.3542, Training Accuracy: 32.36%, Validation Loss: 1.2284, Validation Accuracy: 51.20%
# Epoch 2/100, Training Loss: 1.2112, Training Accuracy: 47.39%, Validation Loss: 1.1584, Validation Accuracy: 51.20%
# Epoch 3/100, Training Loss: 1.1677, Training Accuracy: 50.57%, Validation Loss: 1.1170, Validation Accuracy: 52.80%
# Epoch 4/100, Training Loss: 1.1169, Training Accuracy: 49.21%, Validation Loss: 1.0690, Validation Accuracy: 49.20%
# Epoch 5/100, Training Loss: 1.0564, Training Accuracy: 49.50%, Validation Loss: 1.0442, Validation Accuracy: 47.60%
# Epoch 6/100, Training Loss: 1.0377, Training Accuracy: 50.61%, Validation Loss: 1.0580, Validation Accuracy: 45.00%
# Epoch 7/100, Training Loss: 1.0158, Training Accuracy: 50.70%, Validation Loss: 0.9699, Validation Accuracy: 51.00%
# Epoch 8/100, Training Loss: 1.0039, Training Accuracy: 50.43%, Validation Loss: 0.9546, Validation Accuracy: 53.80%
# Epoch 9/100, Training Loss: 0.9827, Training Accuracy: 51.79%, Validation Loss: 1.0171, Validation Accuracy: 47.60%
# Epoch 10/100, Training Loss: 0.9837, Training Accuracy: 51.08%, Validation Loss: 0.9839, Validation Accuracy: 54.40%
# Epoch 11/100, Training Loss: 0.9751, Training Accuracy: 51.06%, Validation Loss: 0.9641, Validation Accuracy: 52.80%
# Epoch 12/100, Training Loss: 0.9741, Training Accuracy: 51.68%, Validation Loss: 0.9503, Validation Accuracy: 50.60%
# Epoch 13/100, Training Loss: 0.9656, Training Accuracy: 51.10%, Validation Loss: 0.9570, Validation Accuracy: 53.60%
# Epoch 14/100, Training Loss: 0.9593, Training Accuracy: 52.86%, Validation Loss: 0.9538, Validation Accuracy: 50.00%
# Epoch 15/100, Training Loss: 0.9488, Training Accuracy: 51.70%, Validation Loss: 0.9662, Validation Accuracy: 50.80%
# Epoch 16/100, Training Loss: 0.9429, Training Accuracy: 51.41%, Validation Loss: 0.9500, Validation Accuracy: 53.20%
# Epoch 17/100, Training Loss: 0.9347, Training Accuracy: 51.39%, Validation Loss: 0.9573, Validation Accuracy: 53.20%
# Epoch 18/100, Training Loss: 0.9470, Training Accuracy: 50.79%, Validation Loss: 0.9348, Validation Accuracy: 50.60%
# Epoch 19/100, Training Loss: 0.9397, Training Accuracy: 50.92%, Validation Loss: 0.9532, Validation Accuracy: 51.00%
# Epoch 20/100, Training Loss: 0.9298, Training Accuracy: 51.90%, Validation Loss: 0.9467, Validation Accuracy: 51.00%
# Epoch 21/100, Training Loss: 0.9272, Training Accuracy: 52.59%, Validation Loss: 0.9452, Validation Accuracy: 52.80%
# Epoch 22/100, Training Loss: 0.9158, Training Accuracy: 52.19%, Validation Loss: 0.9454, Validation Accuracy: 50.40%
# Epoch 23/100, Training Loss: 0.9071, Training Accuracy: 52.48%, Validation Loss: 0.9030, Validation Accuracy: 54.40%
# Epoch 24/100, Training Loss: 0.9163, Training Accuracy: 53.12%, Validation Loss: 0.9098, Validation Accuracy: 54.60%
# Epoch 25/100, Training Loss: 0.8977, Training Accuracy: 52.68%, Validation Loss: 0.9182, Validation Accuracy: 51.80%
# Epoch 26/100, Training Loss: 0.8960, Training Accuracy: 52.90%, Validation Loss: 0.9294, Validation Accuracy: 52.00%
# Epoch 27/100, Training Loss: 0.9120, Training Accuracy: 52.55%, Validation Loss: 0.9472, Validation Accuracy: 53.80%
# Epoch 28/100, Training Loss: 0.8964, Training Accuracy: 53.08%, Validation Loss: 0.9120, Validation Accuracy: 56.40%
# Epoch 29/100, Training Loss: 0.9047, Training Accuracy: 52.46%, Validation Loss: 0.9208, Validation Accuracy: 56.40%
# Epoch 30/100, Training Loss: 0.8911, Training Accuracy: 52.32%, Validation Loss: 0.8981, Validation Accuracy: 52.40%
# Epoch 31/100, Training Loss: 0.8844, Training Accuracy: 52.99%, Validation Loss: 0.9444, Validation Accuracy: 52.60%
# Epoch 32/100, Training Loss: 0.8842, Training Accuracy: 53.55%, Validation Loss: 0.9039, Validation Accuracy: 53.40%
# Epoch 33/100, Training Loss: 0.8731, Training Accuracy: 52.70%, Validation Loss: 0.9297, Validation Accuracy: 52.40%
# Epoch 34/100, Training Loss: 0.8711, Training Accuracy: 52.92%, Validation Loss: 0.9512, Validation Accuracy: 52.00%
# Epoch 35/100, Training Loss: 0.8718, Training Accuracy: 52.21%, Validation Loss: 0.9293, Validation Accuracy: 49.60%
# Epoch 36/100, Training Loss: 0.8762, Training Accuracy: 53.97%, Validation Loss: 0.9180, Validation Accuracy: 53.40%
# Epoch 37/100, Training Loss: 0.8711, Training Accuracy: 52.66%, Validation Loss: 0.9239, Validation Accuracy: 52.40%
# Epoch 38/100, Training Loss: 0.8912, Training Accuracy: 52.79%, Validation Loss: 0.9079, Validation Accuracy: 54.60%
# Epoch 39/100, Training Loss: 0.8603, Training Accuracy: 54.23%, Validation Loss: 0.9226, Validation Accuracy: 51.40%
# Epoch 40/100, Training Loss: 0.8528, Training Accuracy: 52.90%, Validation Loss: 0.9266, Validation Accuracy: 51.40%
# Epoch 41/100, Training Loss: 0.8552, Training Accuracy: 52.77%, Validation Loss: 0.9060, Validation Accuracy: 53.60%
# Epoch 42/100, Training Loss: 0.8394, Training Accuracy: 53.01%, Validation Loss: 0.9157, Validation Accuracy: 52.00%
# Epoch 43/100, Training Loss: 0.8404, Training Accuracy: 53.63%, Validation Loss: 0.9179, Validation Accuracy: 50.00%
# Epoch 44/100, Training Loss: 0.8390, Training Accuracy: 52.99%, Validation Loss: 0.9117, Validation Accuracy: 52.40%
# Epoch 45/100, Training Loss: 0.8494, Training Accuracy: 53.03%, Validation Loss: 0.9406, Validation Accuracy: 53.00%
# Epoch 46/100, Training Loss: 0.8447, Training Accuracy: 53.55%, Validation Loss: 0.9209, Validation Accuracy: 52.20%
# Epoch 47/100, Training Loss: 0.8468, Training Accuracy: 52.68%, Validation Loss: 0.9554, Validation Accuracy: 52.40%
# Epoch 48/100, Training Loss: 0.8350, Training Accuracy: 53.86%, Validation Loss: 0.8880, Validation Accuracy: 56.20%
# Epoch 49/100, Training Loss: 0.8390, Training Accuracy: 53.61%, Validation Loss: 0.9281, Validation Accuracy: 52.20%
# Epoch 50/100, Training Loss: 0.8393, Training Accuracy: 53.77%, Validation Loss: 0.9453, Validation Accuracy: 51.40%
# Epoch 51/100, Training Loss: 0.8197, Training Accuracy: 54.08%, Validation Loss: 0.9843, Validation Accuracy: 51.20%
# Epoch 52/100, Training Loss: 0.8273, Training Accuracy: 53.81%, Validation Loss: 1.0014, Validation Accuracy: 48.40%
# Epoch 53/100, Training Loss: 0.8252, Training Accuracy: 53.95%, Validation Loss: 0.9349, Validation Accuracy: 52.00%
# Epoch 54/100, Training Loss: 0.8098, Training Accuracy: 53.68%, Validation Loss: 0.9519, Validation Accuracy: 51.20%
# Epoch 55/100, Training Loss: 0.8153, Training Accuracy: 53.83%, Validation Loss: 0.9257, Validation Accuracy: 53.00%
# Epoch 56/100, Training Loss: 0.8026, Training Accuracy: 54.55%, Validation Loss: 0.9879, Validation Accuracy: 51.80%
# Epoch 57/100, Training Loss: 0.8163, Training Accuracy: 54.03%, Validation Loss: 0.9472, Validation Accuracy: 51.60%
# Epoch 58/100, Training Loss: 0.8067, Training Accuracy: 54.23%, Validation Loss: 0.9970, Validation Accuracy: 50.20%
# Epoch 59/100, Training Loss: 0.8047, Training Accuracy: 53.86%, Validation Loss: 0.9540, Validation Accuracy: 50.80%
# Epoch 60/100, Training Loss: 0.7960, Training Accuracy: 54.19%, Validation Loss: 0.9870, Validation Accuracy: 49.20%
# Epoch 61/100, Training Loss: 0.7977, Training Accuracy: 54.21%, Validation Loss: 1.0144, Validation Accuracy: 50.20%
# Epoch 62/100, Training Loss: 0.7910, Training Accuracy: 54.81%, Validation Loss: 0.9525, Validation Accuracy: 53.60%
# Epoch 63/100, Training Loss: 0.7936, Training Accuracy: 54.75%, Validation Loss: 0.9845, Validation Accuracy: 52.00%
# Epoch 64/100, Training Loss: 0.8357, Training Accuracy: 54.23%, Validation Loss: 0.9689, Validation Accuracy: 52.60%
# Epoch 65/100, Training Loss: 0.8102, Training Accuracy: 53.97%, Validation Loss: 0.9532, Validation Accuracy: 51.00%
# Epoch 66/100, Training Loss: 0.8036, Training Accuracy: 54.50%, Validation Loss: 1.0247, Validation Accuracy: 50.20%
# Epoch 67/100, Training Loss: 0.8015, Training Accuracy: 53.72%, Validation Loss: 0.9622, Validation Accuracy: 52.40%
# Epoch 68/100, Training Loss: 0.7947, Training Accuracy: 54.81%, Validation Loss: 0.9425, Validation Accuracy: 51.80%
# Epoch 69/100, Training Loss: 0.7862, Training Accuracy: 55.68%, Validation Loss: 0.9431, Validation Accuracy: 49.40%
# Epoch 70/100, Training Loss: 0.7926, Training Accuracy: 54.43%, Validation Loss: 0.9873, Validation Accuracy: 53.00%
# Epoch 71/100, Training Loss: 0.7846, Training Accuracy: 54.83%, Validation Loss: 0.9989, Validation Accuracy: 50.20%
# Epoch 72/100, Training Loss: 0.7702, Training Accuracy: 55.21%, Validation Loss: 1.0481, Validation Accuracy: 50.40%
# Epoch 73/100, Training Loss: 0.7738, Training Accuracy: 55.08%, Validation Loss: 0.9886, Validation Accuracy: 51.20%
# Epoch 74/100, Training Loss: 0.7917, Training Accuracy: 54.90%, Validation Loss: 0.9610, Validation Accuracy: 51.80%
# Epoch 75/100, Training Loss: 0.7730, Training Accuracy: 55.30%, Validation Loss: 1.0353, Validation Accuracy: 53.20%
# Epoch 76/100, Training Loss: 0.7797, Training Accuracy: 54.28%, Validation Loss: 0.9589, Validation Accuracy: 52.40%
# Epoch 77/100, Training Loss: 0.7667, Training Accuracy: 55.39%, Validation Loss: 1.0278, Validation Accuracy: 50.20%
# Epoch 78/100, Training Loss: 0.7652, Training Accuracy: 54.61%, Validation Loss: 1.0340, Validation Accuracy: 48.20%
# Epoch 79/100, Training Loss: 0.7718, Training Accuracy: 55.39%, Validation Loss: 0.9603, Validation Accuracy: 53.60%
# Epoch 80/100, Training Loss: 0.7828, Training Accuracy: 54.15%, Validation Loss: 1.0439, Validation Accuracy: 49.40%
# Epoch 81/100, Training Loss: 0.7655, Training Accuracy: 54.97%, Validation Loss: 1.0467, Validation Accuracy: 51.60%
# Epoch 82/100, Training Loss: 0.7585, Training Accuracy: 55.88%, Validation Loss: 1.0135, Validation Accuracy: 48.80%
# Epoch 83/100, Training Loss: 0.7618, Training Accuracy: 54.50%, Validation Loss: 1.0836, Validation Accuracy: 48.60%
# Epoch 84/100, Training Loss: 0.7620, Training Accuracy: 54.99%, Validation Loss: 0.9828, Validation Accuracy: 50.80%
# Epoch 85/100, Training Loss: 0.7659, Training Accuracy: 54.15%, Validation Loss: 1.1046, Validation Accuracy: 51.20%
# Epoch 86/100, Training Loss: 0.7697, Training Accuracy: 54.50%, Validation Loss: 1.0709, Validation Accuracy: 51.00%
# Epoch 87/100, Training Loss: 0.7573, Training Accuracy: 55.88%, Validation Loss: 1.0734, Validation Accuracy: 50.00%
# Epoch 88/100, Training Loss: 0.7521, Training Accuracy: 55.63%, Validation Loss: 0.9898, Validation Accuracy: 48.60%
# Epoch 89/100, Training Loss: 0.7734, Training Accuracy: 54.81%, Validation Loss: 1.0359, Validation Accuracy: 50.00%
# Epoch 90/100, Training Loss: 0.7527, Training Accuracy: 54.88%, Validation Loss: 1.0271, Validation Accuracy: 49.00%
# Epoch 91/100, Training Loss: 0.7405, Training Accuracy: 55.28%, Validation Loss: 1.0857, Validation Accuracy: 49.00%
# Epoch 92/100, Training Loss: 0.7520, Training Accuracy: 54.23%, Validation Loss: 1.0825, Validation Accuracy: 52.80%
# Epoch 93/100, Training Loss: 0.7530, Training Accuracy: 55.26%, Validation Loss: 1.0720, Validation Accuracy: 48.60%
# Epoch 94/100, Training Loss: 0.7533, Training Accuracy: 55.41%, Validation Loss: 1.0713, Validation Accuracy: 49.20%
# Epoch 95/100, Training Loss: 0.7438, Training Accuracy: 54.97%, Validation Loss: 1.0683, Validation Accuracy: 49.00%
# Epoch 96/100, Training Loss: 0.7297, Training Accuracy: 55.72%, Validation Loss: 1.0458, Validation Accuracy: 51.20%
# Epoch 97/100, Training Loss: 0.7329, Training Accuracy: 55.95%, Validation Loss: 1.1147, Validation Accuracy: 49.80%
# Epoch 98/100, Training Loss: 0.7610, Training Accuracy: 55.35%, Validation Loss: 1.0860, Validation Accuracy: 52.00%
# Epoch 99/100, Training Loss: 0.7908, Training Accuracy: 53.83%, Validation Loss: 0.9657, Validation Accuracy: 51.80%
# Epoch 100/100, Training Loss: 0.7484, Training Accuracy: 54.95%, Validation Loss: 1.0688, Validation Accuracy: 49.60%

# %% [markdown]
# # Model Performance Summary
#
# After training four different types of neural network models on the dataset for 100 epochs each, we observed the following best validation accuracies for each model:
#
# - **Neural Network (NN):** Best validation accuracy of **55.80%** at epoch **66**
# - **Recurrent Neural Network (RNN):** Best validation accuracy of **53.80%** at epoch **82**
# - **Convolutional Neural Network (CNN):** Best validation accuracy of **55.40%** at epoch **97**
# - **Long Short-Term Memory (LSTM):** Best validation accuracy of **56.40%** at epoch **28**
#
# ## Interpretation
#
# The LSTM model achieved the highest validation accuracy among the four models, indicating that it was the most effective at capturing the patterns within the dataset for this particular task. Its ability to remember long-term dependencies likely contributed to its superior performance.
#
# The CNN model also performed well, showing that spatial hierarchies of features are relevant for this task. CNNs, being powerful in extracting patterns from spatial data (like images or time-series), indicate that the dataset's structure can be well-represented using convolutional layers.
#
# The basic Neural Network model showed competitive performance, which suggests that even simple models can capture significant information from the dataset. However, its performance was slightly lower than the LSTM and CNN models.
#
# The RNN model had the lowest validation accuracy. This might be due to the vanishing gradient problem that RNNs are known to suffer from, making it harder for them to learn long-term dependencies in the data.
#
# ## Conclusion
#
# The LSTM model outperformed the other models in terms of validation accuracy, making it the best choice among the ones tested for this particular task. However, the CNN model's close performance suggests that exploring hybrid models, such as ConvLSTM, which combines the strengths of both CNNs and LSTMs, could potentially offer further improvements.
#
# It's also worth noting that all models performed better than random guessing (which would be 25% accuracy for a four-class problem), indicating that they all managed to learn useful patterns from the data.
#
# ## Key Points
#
# - **LSTM's Superiority:** Indicates the importance of capturing long-term dependencies in the dataset.
# - **CNN's Competitive Performance:** Suggests that convolutional layers effectively extract spatial or temporal patterns.
# - **Potential for Hybrid Models:** Given the strengths of both CNNs and LSTMs, exploring models that combine these architectures could yield better results.
# - **Room for Improvement:** While LSTM performed the best, there's still room for improvement. Techniques like hyperparameter tuning, more sophisticated data preprocessing, or using ensemble methods could enhance model performance further.
